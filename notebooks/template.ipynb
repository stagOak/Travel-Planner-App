# %% [markdown]
# ## import packages

# %%
import sys
import time
from pathlib import Path
import os
import pandas as pd

import os
import pyfredapi as pf
from dotenv import load_dotenv

pd.options.display.max_columns = None
pd.set_option('future.no_silent_downcasting', True)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # set up for imports of .py modules by adding path to sys.path

# %%
path = Path(os.getcwd())
path = str(path.parent.parent)
print(path)
sys.path.insert(1, path)

# %% [markdown]
# # import python modules

# %%
import src.api_utils.dotenv_utils as dotenv_utils

# %% [markdown]
# # helpful functions

# %% [markdown]
# # parameters

# %% [markdown]
# # set the fred 2 api key

# %%
dotenv_utils.dotenv_util('FRED_2_API_KEY')

# %% [markdown]
# # set up to time script run time

# %%
start = time.time()

# %% [markdown]
# # get the data

# %%
# The library automatically uses the key from the environment variable
sp500_data = pf.get_series(series_id='SP500')
sp500_info = pf.get_series_info(series_id='SP500')
print(sp500_info)
sp500_data

# %% [markdown]
# # do stuff to data

# %% [markdown]
# # check out script run time

# %%
end = time.time()
print(f'script run time: {(end - start)/60} minutes')
